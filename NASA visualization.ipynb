# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('clean-std-norm-nasa.csv')

# %%
data.head()
# Out:
#    time  time.1  Rad Flow  Fpv Close  Fpv Open      High    Bypass  Bpv Open  \
# 0 -4821   -4821  0.437500   0.507015  0.333333  0.638093  0.575163  0.656501
# 1 -4624   -4624  0.429688   0.507401  0.358974  0.638212  0.568627  0.630819
# 2 -4475   -4475  0.664062   0.506500  0.349359  0.638522  0.764706  0.686998
# 3 -4184   -4184  0.664062   0.512164  0.355769  0.637878  0.764706  0.682183
# 4 -4048   -4048  0.656250   0.507015  0.358974  0.638117  0.758170  0.677368
#
#    Bpv Close  class  outlier
# 0   0.598071      7        1
# 1   0.575563      7        1
# 2   0.581994      7        1
# 3   0.578778      7        1
# 4   0.572347      1        0

# %%
data.boxplot(column=['Rad Flow','Fpv Close','Fpv Open','High','Bypass','Bpv Open','Bpv Close'],grid=False, rot=45, fontsize=15)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.rename(columns = {'Rad Flow':'RadFlow', 'Fpv Close':'FpvClose', 'Fpv Open': 'FpvOpen','Bpv Open':'BpvOpen',
                              'Bpv Close':'BpvClose'}, inplace = True)

# %%
sns.distplot(data)

# %%
g = sns.FacetGrid(data, col='class', hue="class", palette="Set1")
g = (g.map(sns.distplot, 'RadFlow', hist=False, rug=True))

# %%
sns.pairplot(data,vars=['RadFlow','FpvClose','FpvOpen','High','Bypass','BpvOpen','BpvClose'],hue='class')
plt.show()
# Out:
# /usr/local/anaconda/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
